# %% [markdown]
# <a href="https://colab.research.google.com/github/prem91sagar/PS4HouseDataExercise/blob/master/ps4_Predict_House_Prices_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# House Sales Data, ETL, Build Predictive Model(linear regression), 
# Assess Model, Deploy Model   'houseSmallData.csv' and "data_description.txt"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### data_description.txt
# SalePrice — the property’s sale price in dollars. This is the target variable that you’re trying to predict.
# MSSubClass — The building class
# MSZoning — The general zoning classification
# MasVnrArea - Masonary Veneer Area in sq ft
# LotFrontage — Linear feet of street connected to property
# LotArea — Lot size in square feet
# Street — Type of road access
# Alley — Type of alley access
# LotShape — General shape of property
# LandContour — Flatness of the property
# Utilities — Type of utilities available
# LotConfig — Lot configuration

# %%
data = pd.read_csv('train.csv')

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# $$Y = X_{1}\beta_{1} + X_{2}\beta_{2} + X_{3}\beta_{3}...$$

# %%
data = pd.read_csv('train.csv')
#print(data.shape)
train = data.iloc[:1000,:].copy()

train.to_json('housedata.json')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#pd.get_dummies(train.MSSubClass)

# %% [markdown]
# # New Section

# %%
# investigate Sale Price
train['SalePrice']
# Out:
# 0      208500
# 1      181500
# 2      223500
# 3      140000
# 4      250000
#         ...
# 995    121600
# 996    136500
# 997    185000
# 998     91000
# 999    206000
# Name: SalePrice, Length: 1000, dtype: int64

# %%
# plot hist
plt.hist(train['SalePrice'])
# Out:
# (array([ 99., 493., 254.,  93.,  38.,  15.,   4.,   2.,   1.,   1.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <a list of 10 Patch objects>)

# %%
# select numeric columns
# calculate correlation factor
numeric = train.select_dtypes(include=[np.number])
numeric.shape
# Out:
# (1000, 38)

# %%
corr = numeric.corr()
#corr

# %%
cols = np.abs(corr['SalePrice']).sort_values(ascending=False)#  [0:3].index
cols=cols.reset_index()
cols
# Out:
#             index  SalePrice
# 0       SalePrice   1.000000
# 1     OverallQual   0.797666
# 2       GrLivArea   0.734997
# 3      GarageCars   0.658204
# 4      GarageArea   0.647953
# 5     TotalBsmtSF   0.642127
# 6        1stFlrSF   0.627749
# 7    TotRmsAbvGrd   0.570375
# 8        FullBath   0.559980
# 9       YearBuilt   0.527193
# 10   YearRemodAdd   0.526195
# 11    GarageYrBlt   0.493995
# 12     MasVnrArea   0.492889
# 13     Fireplaces   0.473011
# 14     BsmtFinSF1   0.389868
# 15    LotFrontage   0.371281
# 16       2ndFlrSF   0.325329
# 17     WoodDeckSF   0.324953
# 18    OpenPorchSF   0.319551
# 19       HalfBath   0.304008
# 20        LotArea   0.265493
# 21      BsmtUnfSF   0.221219
# 22   BsmtFullBath   0.216566
# 23   BedroomAbvGr   0.173287
# 24    ScreenPorch   0.140744
# 25   KitchenAbvGr   0.132654
# 26  EnclosedPorch   0.111712
# 27    OverallCond   0.095816
# 28     MSSubClass   0.081252
# 29        MiscVal   0.039521
# 30         MoSold   0.039314
# ...

# %%
cols=cols["index"][:20]
cols
# Out:
# 0        SalePrice
# 1      OverallQual
# 2        GrLivArea
# 3       GarageCars
# 4       GarageArea
# 5      TotalBsmtSF
# 6         1stFlrSF
# 7     TotRmsAbvGrd
# 8         FullBath
# 9        YearBuilt
# 10    YearRemodAdd
# 11     GarageYrBlt
# 12      MasVnrArea
# 13      Fireplaces
# 14      BsmtFinSF1
# 15     LotFrontage
# 16        2ndFlrSF
# 17      WoodDeckSF
# 18     OpenPorchSF
# 19        HalfBath
# Name: index, dtype: object

# %%
# pick out X cols and Y = SalePricee
X = train[cols]
Y = train['SalePrice']
X = X.drop(['SalePrice'], axis = 1)
X
# Out:
#      OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0              7       1710           2         548          856       856
# 1              6       1262           2         460         1262      1262
# 2              7       1786           2         608          920       920
# 3              7       1717           3         642          756       961
# 4              8       2198           3         836         1145      1145
# ..           ...        ...         ...         ...          ...       ...
# 995            4       1230           1         305          747       774
# 996            5       1050           1         368         1050      1050
# 997            6       1442           2         615         1442      1442
# 998            3       1077           1         210         1007      1077
# 999            7       1208           2         632         1187      1208
#
# ...

# %%
X.fillna(X.mean(),inplace=True)

# %%
X.isnull().any()
# Out:
# OverallQual     False
# GrLivArea       False
# GarageCars      False
# GarageArea      False
# TotalBsmtSF     False
# 1stFlrSF        False
# TotRmsAbvGrd    False
# FullBath        False
# YearBuilt       False
# YearRemodAdd    False
# GarageYrBlt     False
# MasVnrArea      False
# Fireplaces      False
# BsmtFinSF1      False
# LotFrontage     False
# 2ndFlrSF        False
# WoodDeckSF      False
# OpenPorchSF     False
# HalfBath        False
# dtype: bool

# %%
# buld Linear Regression Model
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X, Y)
predictions = model.predict(X)

# %%
# How good is the model
model.score(X,Y)
# Out:
# 0.8296486642539092

# %%
# Scatter plot of predictions
plt.scatter(predictions, Y)

# %%
#  test data

# %%
test=pd.read_csv("test.csv")

# %%
test
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1001          20       RL         74.0    10206   Pave   NaN      Reg
# 1    1002          30       RL         60.0     5400   Pave   NaN      Reg
# 2    1003          20       RL         75.0    11957   Pave   NaN      IR1
# 3    1004          90       RL          NaN    11500   Pave   NaN      IR1
# 4    1005         120       RL         43.0     3182   Pave   NaN      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
X.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF',
#        '1stFlrSF', 'TotRmsAbvGrd', 'FullBath', 'YearBuilt', 'YearRemodAdd',
#        'GarageYrBlt', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'LotFrontage',
#        '2ndFlrSF', 'WoodDeckSF', 'OpenPorchSF', 'HalfBath'],
#       dtype='object')

# %%
test=test[[column for column in X.columns if column in test.columns]]

# %%
test
# Out:
#      OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0              3        944           2         528            0       944
# 1              5        691           1         216          691       691
# 2              8       1574           3         824         1574      1574
# 3              5       1680           2         528         1680      1680
# 4              7       1504           2         457         1346      1504
# ..           ...        ...         ...         ...          ...       ...
# 455            6       1647           2         460          953       953
# 456            6       2073           2         500         1542      2073
# 457            7       2340           1         252         1152      1188
# 458            5       1078           1         240         1078      1078
# 459            5       1256           1         276         1256      1256
#
# ...

# %%
test.fillna(test.mean(),inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
y_pred=model.predict(test)

y_pred=pd.DataFrame(y_pred)

y_pred.index=np.arange(0,460)
y_pred.reset_index(inplace=True)

# %%
y_pred=np.round(y_pred,2)
y_pred
# Out:
#      index          0
# 0        0   40411.10
# 1        1   55915.78
# 2        2  252275.87
# 3        3  170172.41
# 4        4  206326.43
# ..     ...        ...
# 455    455  180244.04
# 456    456  247466.26
# 457    457  233267.86
# 458    458  122285.92
# 459    459  157191.69
#
# [460 rows x 2 columns]

# %%
y_pred.columns=["Id","SalePrice"]

# %%
y_pred.to_csv("testDataPrediction.csv")
